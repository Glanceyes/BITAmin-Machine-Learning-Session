# %% [markdown]
# movie 데이터를 불러와 df에 저장해주세요!

# %%
import pandas as pd
df = pd.read_csv('movieinfo.csv')

# %% [markdown]
# ### 문제 1
# 열별 결측치를 확인하고 결측치를 각 열의 평균값으로 바꿔주세요

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df
# Out:
#       color      director_name  num_critic_for_reviews    duration  \
# 0     Color      James Cameron              722.000000  178.000000
# 1     Color     Gore Verbinski              302.000000  169.000000
# 2     Color         Sam Mendes              602.000000  148.000000
# 3     Color  Christopher Nolan              813.000000  164.000000
# 4       NaN        Doug Walker              137.988699  107.090798
# ...     ...                ...                     ...         ...
# 4911  Color        Scott Smith                1.000000   87.000000
# 4912  Color                NaN               43.000000   43.000000
# 4913  Color   Benjamin Roberds               13.000000   76.000000
# 4914  Color        Daniel Hsia               14.000000  100.000000
# 4915  Color           Jon Gunn               43.000000   90.000000
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                    0.000000              855.000000  Joel David Moore
# 1                  563.000000             1000.000000     Orlando Bloom
# 2                    0.000000              161.000000      Rory Kinnear
# 3                22000.000000            23000.000000    Christian Bale
# 4                  131.000000              631.276313        Rob Walker
# ...                       ...                     ...               ...
# 4911                 2.000000              318.000000     Daphne Zuniga
# 4912               691.014541              319.000000     Valorie Curry
# 4913                 0.000000                0.000000     Maxwell Moody
# 4914                 0.000000              489.000000     Daniel Henney
# 4915                16.000000               16.000000  Brian Herzlinger
#
#       actor_1_facebook_likes         gross                           genres  \
# 0                     1000.0  7.605058e+08  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  3.094042e+08         Action|Adventure|Fantasy
# 2                    11000.0  2.000742e+08        Action|Adventure|Thriller
# 3                    27000.0  4.481306e+08                  Action|Thriller
# 4                      131.0  4.764451e+07                      Documentary
# ...                      ...           ...                              ...
# 4911                   637.0  4.764451e+07                     Comedy|Drama
# 4912                   841.0  4.764451e+07     Crime|Drama|Mystery|Thriller
# 4913                     0.0  4.764451e+07            Drama|Horror|Thriller
# 4914                   946.0  1.044300e+04             Comedy|Drama|Romance
# 4915                    86.0  8.522200e+04                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating  \
# 0     ...          3054.000000  English      USA           PG-13
# 1     ...          1238.000000  English      USA           PG-13
# 2     ...           994.000000  English       UK           PG-13
# 3     ...          2701.000000  English      USA           PG-13
# 4     ...           267.668846      NaN      NaN             NaN
# ...   ...                  ...      ...      ...             ...
# 4911  ...             6.000000  English   Canada             NaN
# 4912  ...           359.000000  English      USA           TV-14
# 4913  ...             3.000000  English      USA             NaN
# 4914  ...             9.000000  English      USA           PG-13
# 4915  ...            84.000000  English      USA              PG
#
#             budget   title_year actor_2_facebook_likes imdb_score  \
# 0     2.370000e+08  2009.000000                  936.0        7.9
# 1     3.000000e+08  2007.000000                 5000.0        7.1
# 2     2.450000e+08  2015.000000                  393.0        6.8
# 3     2.500000e+08  2012.000000                23000.0        8.5
# 4     3.654749e+07  2002.447609                   12.0        7.1
# ...            ...          ...                    ...        ...
# 4911  3.654749e+07  2013.000000                  470.0        7.7
# 4912  3.654749e+07  2002.447609                  593.0        7.5
# 4913  1.400000e+03  2013.000000                    0.0        6.3
# 4914  3.654749e+07  2012.000000                  719.0        6.3
# 4915  1.100000e+03  2004.000000                   23.0        6.6
#
#       aspect_ratio movie_facebook_likes
# 0         1.780000                33000
# 1         2.350000                    0
# 2         2.350000                85000
# 3         2.350000               164000
# 4         2.222349                    0
# ...            ...                  ...
# 4911      2.222349                   84
# 4912     16.000000                32000
# 4913      2.222349                   16
# 4914      2.350000                  660
# 4915      1.850000                  456
#
# [4916 rows x 28 columns]

# %% [markdown]
# ### 문제2
# astype을 이용해 num_critic_for_reviews와 gross열의 데이터타입을 int64로 바꿔주세요

# %%
df = df.astype({'num_critic_for_reviews':'int64', 'gross':'int64'})
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews         int64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                          int64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %% [markdown]
# ### 문제3
# 불린 인덱싱을 통해 num_critic_for reviews 가 500 이상이고 gross가 열의 75% 분위수 이상인 행만 뽑아 df1에 저장해주세요

# %%
df1 = df[(df['num_critic_for_reviews']>=500) & (df['gross'] >= df.gross.quantile(.75))]
df1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                     722     178.0
# 2     Color         Sam Mendes                     602     148.0
# 3     Color  Christopher Nolan                     813     164.0
# 8     Color        Joss Whedon                     635     141.0
# 10    Color        Zack Snyder                     673     183.0
# ...     ...                ...                     ...       ...
# 2139  Color          James Wan                     511     112.0
# 2145  Color    Alexander Payne                     549     115.0
# 2148  Color      Steve McQueen                     597     134.0
# 2482  Color       Fede Alvarez                     543      96.0
# 2790  Color   Darren Aronofsky                     669     108.0
#
#       director_facebook_likes  actor_3_facebook_likes         actor_2_name  \
# 0                         0.0                   855.0     Joel David Moore
# 2                         0.0                   161.0         Rory Kinnear
# 3                     22000.0                 23000.0       Christian Bale
# 8                         0.0                 19000.0    Robert Downey Jr.
# 10                        0.0                  2000.0         Lauren Cohan
# ...                       ...                     ...                  ...
# 2139                      0.0                   697.0          Lili Taylor
# 2145                    729.0                   552.0          Nick Krause
# 2148                      0.0                   500.0        Scoot McNairy
# 2482                    201.0                    58.0  Elizabeth Blackmore
# 2790                      0.0                  1000.0           Mila Kunis
#
#       actor_1_facebook_likes      gross                           genres  ...  \
# 0                     1000.0  760505847  Action|Adventure|Fantasy|Sci-Fi  ...
# 2                    11000.0  200074175        Action|Adventure|Thriller  ...
# 3                    27000.0  448130642                  Action|Thriller  ...
# 8                    26000.0  458991599          Action|Adventure|Sci-Fi  ...
# 10                   15000.0  330249062          Action|Adventure|Sci-Fi  ...
# ...                      ...        ...                              ...  ...
# 2139                  6000.0  137387272          Horror|Mystery|Thriller  ...
# 2145                  8000.0   82624961                     Comedy|Drama  ...
# 2148                  2000.0   56667870          Biography|Drama|History  ...
# 2482                   394.0   54239856                           Horror  ...
# 2790                 20000.0  106952327                   Drama|Thriller  ...
#
#      num_user_for_reviews language  country  content_rating       budget  \
# 0                  3054.0  English      USA           PG-13  237000000.0
# 2                   994.0  English       UK           PG-13  245000000.0
# 3                  2701.0  English      USA           PG-13  250000000.0
# 8                  1117.0  English      USA           PG-13  250000000.0
# 10                 3018.0  English      USA           PG-13  250000000.0
# ...                   ...      ...      ...             ...          ...
# 2139                807.0  English      USA               R   20000000.0
# 2145                439.0  English      USA               R   20000000.0
# 2148                695.0  English      USA               R   20000000.0
# 2482                789.0  English      USA               R   17000000.0
# 2790               1140.0  English      USA               R   13000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 8         2015.0                21000.0        7.5          2.35
# 10        2016.0                 4000.0        6.9          2.35
# ...          ...                    ...        ...           ...
# 2139      2013.0                  960.0        7.5          2.35
# 2145      2011.0                  727.0        7.3          2.35
# 2148      2013.0                  660.0        8.1          2.35
# 2482      2013.0                  150.0        6.5          2.35
# 2790      2010.0                15000.0        8.0          2.35
#
#      movie_facebook_likes
# 0                   33000
# 2                   85000
# 3                  164000
# 8                  118000
# 10                 197000
# ...                   ...
# 2139               131000
# 2145                22000
# 2148                83000
# 2482                70000
# 2790               106000
#
# [66 rows x 28 columns]

# %% [markdown]
# ### 문제4
# df1에서 director_facebook_likes가 가장 높은 영화의 감독 이름을 k라는 변수에 할당해주세요 (method chaining 사용, 인덱스 유의)

# %%
k = df1.sort_values(by='director_facebook_likes', ascending=False).iloc[0,4]
k
# Out:
# 22000.0

# %% [markdown]
# ### 문제4-1
# 위의 영화 감독이 만든 영화를 모두 뽑고 그 영화들의 imdb score 평균을 구해주세요 (query 사용, method chaining)

# %%
df1.query('director_facebook_likes == @k')['imdb_score'].mean()
# Out:
# 8.725000000000001
